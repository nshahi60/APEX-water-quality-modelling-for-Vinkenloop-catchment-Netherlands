# %%
import pandas as pd
import numpy as np
import matplotlib as plt

data=pd.read_csv("C:/Users/shahi/Downloads/TxtInOut_APEX1501_modified/TxtInOut/SITE14.DMR", skiprows=9, delimiter='\\s+')

data.head(100)
#data.columns
# Out:
#     JDA    YR        WYLDmm        Yppm     YNppm    YPppm     QNppm     QPppm
# 0     1  1997  1.157840e+06    0.000342  0.000000  0.00000   0.00000  0.000000
# 1     2  1997  1.047830e+06    0.000339  0.000000  0.00000   0.00000  0.000000
# 2     3  1997  9.481670e+05    0.000336  0.000000  0.00000   0.00000  0.000000
# 3     4  1997  8.579320e+05    0.000334  0.000000  0.00000   0.00000  0.000000
# 4     5  1997  7.761940e+05    0.000332  0.000000  0.00000   0.00000  0.000000
# ..  ...   ...           ...         ...       ...      ...       ...       ...
# 95   96  1997  4.339560e-04    0.000000  0.000000  0.00000   3.81408  0.000000
# 96   97  1997  1.574520e+05  112.648000  0.213827  0.03919  10.80040  0.033128
# 97   98  1997  3.011060e-01    0.000000  0.000000  0.00000   5.63006  0.000000
# 98   99  1997  1.337760e-01    0.000000  0.000000  0.00000   5.44531  0.000000
# 99  100  1997  6.018230e-02    0.000000  0.000000  0.00000   5.24681  0.000000
#
# [100 rows x 8 columns]

# %%
#data['JDA']=
data.plot(y='QNppm', xlabel="Number of days since 01/01/1997", ylabel="Soluble nitrate concentration in surface runoff(ppm)")

#Use jda and year to plot regular dates on x-axis
#Put x-axis labels
# Out:
# <Axes: xlabel='Number of days since 01/01/1997', ylabel='Soluble nitrate concentration in surface runoff(ppm)'>
